# %%
from openai import OpenAI

client = OpenAI()

response = client.responses.create(
    model="gpt-5.4-mini",
    input="Tell me what is a data domain"
)

print(response.output_text)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 from openai import OpenAI
#       2
# ----> 3 client = OpenAI()
#       4
#       5 response = client.response.create(
#       6     model="gpt-5.4-mini",
#
# File d:\zukunftDatumEntwickler\sv-data-engineering-portfolio\.venv\Lib\site-packages\openai\_client.py:271, in OpenAI.__init__(self, api_key, admin_api_key, workload_identity, organization, project, webhook_secret, provider, base_url, data_residency, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation, _enforce_credentials)
#     261 self.admin_api_key = admin_api_key if provider_runtime is None else None
#     263 if (
#     264     provider_runtime is None
#     265     and _enforce_credentials
#    (...)    269     and self.admin_api_key is None
#     270 ):
# ...
